# %% [markdown]
# ## Install & Test WMLA Python client
#
# This notebook covers installation WMLA Python client.
#
# 1. Install WMLA Python client
# 2. Test connection using Python client

# %% [markdown]
# Import ibm-watson-studio-lib library for Python
# - To access to assets in Watson Studio
#
# Refernce: https://www.ibm.com/docs/en/cloud-paks/cp-data/4.5.x?topic=lib-watson-studio-python

# %%
from ibm_watson_studio_lib import access_project_or_space
wslib = access_project_or_space()

# %% [markdown]
# ## 1. Install WMLA Python client
#
# Download package zip file
# - ibm_wmla_packages.zip

# %%
wslib.download_file("ibm_wmla_packages.zip", "ibm_wmla_packages.zip")
# Out:
# {'file_name': 'ibm_wmla_packages.zip',
#  'summary': ['loaded data', 'saved to file']}

# %% [markdown]
# unzip target file

# %%
## unzip the file
# !unzip ibm_wmla_packages.zip && cd ibm_wmla_packages
# !ls -l
# Out:
# Archive:  ibm_wmla_packages.zip
#    creating: ibm_wmla_packages/
#    creating: ibm_wmla_packages/cp4d_install/
#   inflating: ibm_wmla_packages/ibm_wmla_client-0.1.1-py3-none-any.whl
#   inflating: ibm_wmla_packages/ibm_wmla-0.1.1-py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/.DS_Store
#   inflating: __MACOSX/ibm_wmla_packages/cp4d_install/._.DS_Store
#    creating: ibm_wmla_packages/cp4d_install/whl_files/
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/certifi-2022.6.15-py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/PyJWT-2.4.0-py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/python_dateutil-2.8.2-py2.py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/requests-2.28.1-py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/charset_normalizer-2.1.0-py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/urllib3-1.26.11-py2.py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/ibm_cloud_sdk_core-3.16.0-py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/six-1.16.0-py2.py3-none-any.whl
#   inflating: ibm_wmla_packages/cp4d_install/whl_files/idna-3.3-py3-none-any.whl
# total 876
# drwxr-xr-x. 3 1000700000 wscommon    111 Aug  9 03:44 ibm_wmla_packages
# -rw-rw----. 1 1000700000 wscommon 893322 Aug  9 05:45 ibm_wmla_packages.zip
# drwxrwx---. 3 1000700000 wscommon     31 Aug  9 05:45 __MACOSX

# %% [markdown]
# install ibm_wmla

# %%
# !cd ibm_wmla_packages && pip install --no-index --find-links cp4d_install/whl_files ibm_wmla-0.1.1-py3-none-any.whl
# Out:
# Looking in links: cp4d_install/whl_files
# Processing ./ibm_wmla-0.1.1-py3-none-any.whl
# Processing ./cp4d_install/whl_files/ibm_cloud_sdk_core-3.16.0-py3-none-any.whl
# Requirement already satisfied: python_dateutil<3.0.0,>=2.5.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wmla==0.1.1) (2.8.2)
# Requirement already satisfied: requests<3.0,>=2.20 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wmla==0.1.1) (2.26.0)
# Processing ./cp4d_install/whl_files/PyJWT-2.4.0-py3-none-any.whl
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.15.3->ibm-wmla==0.1.1) (1.26.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from python_dateutil<3.0.0,>=2.5.3->ibm-wmla==0.1.1) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.20->ibm-wmla==0.1.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.20->ibm-wmla==0.1.1) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.20->ibm-wmla==0.1.1) (3.3)
# Installing collected packages: PyJWT, ibm-cloud-sdk-core, ibm-wmla
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.1.0
#     Uninstalling PyJWT-2.1.0:
#       Successfully uninstalled PyJWT-2.1.0
#   Attempting uninstall: ibm-cloud-sdk-core
#     Found existing installation: ibm-cloud-sdk-core 3.10.1
#     Uninstalling ibm-cloud-sdk-core-3.10.1:
#       Successfully uninstalled ibm-cloud-sdk-core-3.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibm-watson-openscale 3.0.14 requires ibm-cloud-sdk-core==3.10.1, but you have ibm-cloud-sdk-core 3.16.0 which is incompatible.
# Successfully installed PyJWT-2.4.0 ibm-cloud-sdk-core-3.16.0 ibm-wmla-0.1.1

# %% [markdown]
# install ibm_wmla_client

# %%
# !cd ibm_wmla_packages && pip install ibm_wmla_client-0.1.1-py3-none-any.whl
# Out:
# Processing ./ibm_wmla_client-0.1.1-py3-none-any.whl
# Requirement already satisfied: ibm-cloud-sdk-core<4.0.0,>=3.15.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wmla-client==0.1.1) (3.16.0)
# Requirement already satisfied: requests<3.0,>=2.20 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wmla-client==0.1.1) (2.26.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wmla-client==0.1.1) (1.20.3)
# Requirement already satisfied: ibm-wmla<0.2.0,>=0.1.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wmla-client==0.1.1) (0.1.1)
# Requirement already satisfied: python_dateutil<3.0.0,>=2.5.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-wmla-client==0.1.1) (2.8.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.15.3->ibm-wmla-client==0.1.1) (2.4.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cloud-sdk-core<4.0.0,>=3.15.3->ibm-wmla-client==0.1.1) (1.26.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from python_dateutil<3.0.0,>=2.5.3->ibm-wmla-client==0.1.1) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.20->ibm-wmla-client==0.1.1) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.20->ibm-wmla-client==0.1.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests<3.0,>=2.20->ibm-wmla-client==0.1.1) (3.3)
# Installing collected packages: ibm-wmla-client
# Successfully installed ibm-wmla-client-0.1.1

# %% [markdown]
# ## 2. Test connection using Python client
#
# If we have completed the installation, we can import two libraries (ibm_wala, ibm_wmla_clinet).

# %%
import ibm_wmla
import ibm_wmla_client

# %% [markdown]
# Let's test connection using our library

# %%
from urllib import response
from ibm_wmla_client import Connection
import numpy as np
import os

# %%
# diable warning (unverified HTTPS request)
# please refer: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings

import urllib3
urllib3.disable_warnings()

# %% [markdown]
# Define variables for setup WMLA environment (we will use USER_ACCESS_TOKEN to connect WMLA service)

# %%
service_url = "https://wmla-console-wmla.apps.ocp.tanggle.com"
service_instance = 'ibm_wml_elastic_distributed_inference'

USER_ACCESS_TOKEN = os.getenv('USER_ACCESS_TOKEN')

# %%
edi_connection = Connection(service_url, service_instance, wmla_v1=True, edi=True,
                 apikey=None, username=None, password=None, user_access_token = USER_ACCESS_TOKEN)

# %%
edi_connection.connect()
# Out:
# Connecting to EDI
# EDI Token created
# EDI Service connected

# %%
conn = edi_connection.service_edi

# %% [markdown]
# get model's list and its information

# %%
print(conn.get_models(verify=False))
# Out:
# {
#     "result": [
#         {
#             "name": "pingpong",
#             "uid": "03105212-74f6-48eb-a8bf-114649943645",
#             "tag": "test",
#             "size": 4266,
#             "weight_path": "model",
#             "model_path": "/opt/wml-edi/repo/pingpong/pingpong-20220622-131252",
#             "create_time": 1655903572,
#             "last_updated_time": 1655903572,
#             "started_at": 1659419890,
#             "creator": "admin",
#             "runtime": "condaenvpy39",
#             "kernel_path": "kernel.py",
#             "service_uri": "https://wmla-inference-wmla.apps.ocp.tanggle.com/dlim/v1/inference/pingpong",
#             "attributes": [],
#             "mk_environments": [],
#             "schema_version": "1",
#             "stream_uri": "10.100.6.42:8890"
#         },
#         {
#             "name": "resnet18-jihunkim",
#             "uid": "db568a28-cced-4704-ae87-bc385dd2c4cb",
#             "tag": "",
#             "size": 104067,
#             "weight_path": "./",
#             "model_path": "/opt/wml-edi/repo/resnet18-jihunkim/resnet18-jihunkim-20220725-081603",
#             "create_time": 1658736963,
#             "last_updated_time": 1658736963,
#             "started_at": 1658795104,
#             "creator": "jihun.kim",
#             "runtime": "dlipy3",
#             "kernel_path": "kernel.py",
#             "service_uri": "https://wmla-inference-wmla.apps.ocp.tanggle.com/dlim/v1/inference/resnet18-jihunkim",
#             "attributes": [],
#             "mk_environments": [],
#             "schema_version": "1",
#             "stream_uri": "10.100.12.10:8890"
#         },
#         {
#             "name": "resnet18-pytorch",
#             "uid": "a722337f-13f0-404a-9d54-a2d8bdc30828",
#             "tag": "",
#             "size": 44790650,
#             "weight_path": "./",
#             "model_path": "/opt/wml-edi/repo/resnet18-pytorch/resnet18-pytorch-20220720-073638",
#             "create_time": 1658302598,
#             "last_updated_time": 1658302598,
#             "started_at": 0,
#             "creator": "admin",
#             "runtime": "dlipy3",
#             "kernel_path": "kernel.py",
#             "service_uri": "",
#             "attributes": [],
#             "mk_environments": [],
#             "schema_version": "1"
#         },
#         {
#             "name": "tf-cifar10",
#             "uid": "a6e30df0-f6d8-45f5-a9c4-f156d66d3af2",
#             "tag": "cifar10 images",
#             "size": 9038892,
#             "weight_path": "model",
#             "model_path": "/opt/wml-edi/repo/tf-cifar10/tf-cifar10-20220804-141150",
#             "create_time": 1659622310,
#             "last_updated_time": 1659622310,
#             "started_at": 0,
#             "creator": "jihun.kim",
#             "runtime": "mydlipy3",
#             "kernel_path": "kernel.py",
#             "service_uri": "",
#             "attributes": [],
#             "mk_environments": [],
#             "schema_version": "1"
#         }
#     ],
#     "headers": {
#         "_store": {
#             "server": [
#                 "Server",
#                 "nginx/1.20.2"
#             ],
#             "date": [
#                 "Date",
#                 "Tue, 09 Aug 2022 05:45:57 GMT"
#             ],
#             "content-type": [
#                 "Content-Type",
#                 "text/html; charset=ISO-8859-1"
#             ],
#             "transfer-encoding": [
#                 "Transfer-Encoding",
#                 "chunked"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ],
#             "access-control-allow-methods": [
#                 "Access-Control-Allow-Methods",
#                 "GET,PUT,POST,DELETE"
#             ],
#             "access-control-allow-credentials": [
#                 "Access-Control-Allow-Credentials",
#                 "true"
#             ],
#             "access-control-allow-headers": [
#                 "Access-Control-Allow-Headers",
#                 "Authorization,Accept-Language,Accept,Content-Type,Range,Origin,X-Requested-With,X-File-Name"
#             ],
#             "access-control-expose-headers": [
#                 "Access-Control-Expose-Headers",
#                 "Content-Range"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %% [markdown]
# get details of the model (pingpong)

# %%
print(conn.get_model("pingpong"))
# Out:
# {
#     "result": {
#         "name": "pingpong",
#         "uid": "03105212-74f6-48eb-a8bf-114649943645",
#         "tag": "test",
#         "size": 4266,
#         "weight_path": "model",
#         "model_path": "/opt/wml-edi/repo/pingpong/pingpong-20220622-131252",
#         "create_time": 1655903572,
#         "last_updated_time": 1655903572,
#         "started_at": 1659419890,
#         "creator": "admin",
#         "runtime": "condaenvpy39",
#         "kernel_path": "kernel.py",
#         "service_uri": "https://wmla-inference-wmla.apps.ocp.tanggle.com/dlim/v1/inference/pingpong",
#         "attributes": [],
#         "mk_environments": [],
#         "schema_version": "1",
#         "stream_uri": "10.100.6.42:8890"
#     },
#     "headers": {
#         "_store": {
#             "server": [
#                 "Server",
#                 "nginx/1.20.2"
#             ],
#             "date": [
#                 "Date",
#                 "Tue, 09 Aug 2022 05:45:57 GMT"
#             ],
#             "content-type": [
#                 "Content-Type",
#                 "text/html; charset=ISO-8859-1"
#             ],
#             "transfer-encoding": [
#                 "Transfer-Encoding",
#                 "chunked"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ],
#             "access-control-allow-methods": [
#                 "Access-Control-Allow-Methods",
#                 "GET,PUT,POST,DELETE"
#             ],
#             "access-control-allow-credentials": [
#                 "Access-Control-Allow-Credentials",
#                 "true"
#             ],
#             "access-control-allow-headers": [
#                 "Access-Control-Allow-Headers",
#                 "Authorization,Accept-Language,Accept,Content-Type,Range,Origin,X-Requested-With,X-File-Name"
#             ],
#             "access-control-expose-headers": [
#                 "Access-Control-Expose-Headers",
#                 "Content-Range"
#             ]
#         }
#     },
#     "status_code": 200
# }
